# %%
import altair as alt
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_bcubcg_fall2022/main/data/bfro_reports_fall2022.csv')
df.head()
# Out:
#                                             observed  \
# 0  Ed L. was salmon fishing with a companion in P...
# 1  heh i kinda feel a little dumb that im reporti...
# 2  I was on my way to Claremont from Lebanon on R...
# 3  I was northeast of Macy Nebraska along the Mis...
# 4  While this incident occurred a long time ago, ...
#
#                                     location_details  \
# 0                  East side of Prince William Sound
# 1  the road is off us rt 80, i dont know the exit...
# 2  Close to Claremont down 120 not far from Kings...
# 3      Latitude & Longitude :  42.158230  -96.344197
# 4  Ward County, Just outside of a the Minuteman T...
#
#                            county          state  season  \
# 0  Valdez-Chitina-Whittier County         Alaska    Fall
# 1                   Warren County     New Jersey    Fall
# 2                 Sullivan County  New Hampshire  Summer
# 3                 Thurston County       Nebraska  Spring
# ...

# %%
df.columns
# Out:
# Index(['observed', 'location_details', 'county', 'state', 'season', 'title',
#        'latitude', 'longitude', 'date', 'number', 'classification', 'geohash',
#        'temperature_high', 'temperature_mid', 'temperature_low', 'dew_point',
#        'humidity', 'cloud_cover', 'moon_phase', 'precip_intensity',
#        'precip_probability', 'precip_type', 'pressure', 'summary', 'uv_index',
#        'visibility', 'wind_bearing', 'wind_speed', 'location'],
#       dtype='object')

# %%
df_first_plot = df[['state','temperature_mid', 'humidity', 'precip_type']]
df_first_plot.head()
# Out:
#            state  temperature_mid  humidity precip_type
# 0         Alaska              NaN       NaN         NaN
# 1     New Jersey              NaN       NaN         NaN
# 2  New Hampshire           64.245      0.79        rain
# 3       Nebraska           77.700      0.61         NaN
# 4   North Dakota           58.955      0.32        rain

# %%
df_first_plot['precip_type'].unique()
# Out:
# array([nan, 'rain', 'snow'], dtype=object)

# %%
df_first_plot['temperature_mid'].unique()
# Out:
# array([   nan, 64.245, 77.7  , ..., 75.22 , 22.665, 75.76 ])

# %%
df_first_plot['humidity'].unique()
# Out:
# array([ nan, 0.79, 0.61, 0.32, 0.75, 0.72, 0.59, 0.6 , 0.77, 0.67, 0.95,
#        0.5 , 0.52, 0.74, 0.73, 0.3 , 0.89, 0.64, 0.41, 0.87, 0.29, 0.35,
#        0.7 , 0.8 , 0.83, 0.63, 0.88, 0.66, 0.85, 0.55, 0.91, 0.62, 0.69,
#        0.78, 0.86, 0.82, 0.81, 0.68, 1.  , 0.71, 0.9 , 0.65, 0.92, 0.94,
#        0.4 , 0.53, 0.49, 0.54, 0.76, 0.93, 0.56, 0.96, 0.46, 0.58, 0.57,
#        0.97, 0.47, 0.43, 0.45, 0.48, 0.51, 0.27, 0.84, 0.37, 0.36, 0.44,
#        0.38, 0.99, 0.42, 0.39, 0.21, 0.14, 0.23, 0.33, 0.98, 0.34, 0.24,
#        0.15, 0.16, 0.26, 0.22, 0.28, 0.25, 0.18, 0.13, 0.31, 0.19])

# %%
df_first_plot.isna().sum()
# Out:
# state                 0
# temperature_mid    1797
# humidity           1614
# precip_type        3187
# dtype: int64

# %%
df_first_plot = df_first_plot.dropna()
df_first_plot.head()
# Out:
#             state  temperature_mid  humidity precip_type
# 2   New Hampshire           64.245      0.79        rain
# 4    North Dakota           58.955      0.32        rain
# 7         Montana            7.445      0.75        snow
# 8        Missouri           40.490      0.72        rain
# 10       Michigan           68.845      0.59        rain

# %%
first_plot = alt.Chart(df_first_plot).mark_circle().encode(
    alt.X("humidity:Q"),
    alt.Y("temperature_mid:Q"),
    alt.Color("precip_type:N"),
    tooltip=['state', 'humidity', 'temperature_mid', 'precip_type']
).properties(
    width=600,
    height=400
).interactive()
first_plot
# Out:
# alt.Chart(...)

# %%
first_plot.properties(width='container').save('HW10_first_plot.json')

# %%
df_second_plot = df[['cloud_cover', 'visibility', 'wind_speed', 'summary', 'season']]
df_second_plot.head()
# Out:
#    cloud_cover  visibility  wind_speed                            summary  \
# 0          NaN         NaN         NaN                                NaN
# 1          NaN         NaN         NaN                                NaN
# 2         0.61        9.70        0.49  Mostly cloudy throughout the day.
# 3         0.06        8.25        3.33      Partly cloudy in the morning.
# 4         0.34       10.00       11.14       Partly cloudy until evening.
#
#    season
# 0    Fall
# 1    Fall
# 2  Summer
# 3  Spring
# 4  Spring

# %%
df_second_plot.isna().sum()
# Out:
# cloud_cover    1894
# visibility     1930
# wind_speed     1598
# summary        1591
# season            0
# dtype: int64

# %%
df_second_plot = df_second_plot.dropna()
df_second_plot.head()
# Out:
#    cloud_cover  visibility  wind_speed  \
# 2         0.61        9.70        0.49
# 3         0.06        8.25        3.33
# 4         0.34       10.00       11.14
# 5         0.46        9.50       16.94
# 7         0.19       10.00        1.10
#
#                                              summary  season
# 2                  Mostly cloudy throughout the day.  Summer
# 3                      Partly cloudy in the morning.  Spring
# 4                       Partly cloudy until evening.  Spring
# 5  Partly cloudy until evening and breezy through...  Spring
# 7  Partly cloudy starting in the afternoon, conti...  Winter

# %%
df_second_plot['season'].unique()
# Out:
# array(['Summer', 'Spring', 'Winter', 'Fall', 'Unknown'], dtype=object)

# %%
df_second_plot = df_second_plot[df_second_plot['season'].str.contains('Unknown') == False]

# %%
df_second_plot['season'].unique()
# Out:
# array(['Summer', 'Spring', 'Winter', 'Fall'], dtype=object)

# %%
second_plot = alt.Chart(df_second_plot).mark_circle().encode(
    alt.X("cloud_cover:Q"),
    alt.Y("visibility:Q"),
    alt.Color("season"),
    size='wind_speed',
    tooltip=['season', 'cloud_cover', 'wind_speed', 'visibility', 'summary']
).properties(
    width=800,
    height=400
).interactive()
second_plot
# Out:
# alt.Chart(...)

# %%
second_plot.properties(width='container').save('HW10_second_plot.json')
